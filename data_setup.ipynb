# %%
import http.client
import json
import pprint


gs_certified_project_list = []

conn = http.client.HTTPSConnection("api.goldstandard.org")
payload = ''
headers = {
  'Content-Type': 'application/json'
}

page_counter = 1

while(True):
  conn.request("GET", f"/projects?size=150&page={page_counter}&gsCertified=true", payload, headers)
  res = conn.getresponse()
  response_json =  json.loads(res.read().decode())

  if(len(response_json) == 0):
    print(f"Data retrieved till page number {page_counter}")
    break;

  gs_certified_project_list += response_json
  page_counter += 1
  #pd.DataFrame(list(zip(lst1, lst2, lst3)))

print(f"Total Gold Standard Certified Project Found are {len(gs_certified_project_list)}")
# Out:
# Data retrieved till page number 11
# Total Gold Standard Certified Project Found are 1362

# %%
# import requests
# import pprint

# retrival_size = 10000
# gsCertified = True

# class API:
#     def __init__(self, endpoint):
#         self.endpoint = endpoint
        
#     def get_data(self):
#         response = requests.request("GET", self.endpoint, headers={}, data={})
#         return response.text

# project_api = API(f"https://api.goldstandard.org/projects?size={retrival_size}&gsCertified={gsCertified}")
# gs_certified_project_list = project_api.get_data()

# print(len(gs_certified_project_list))

# %%
import pandas as pd

project_df = pd.DataFrame(gs_certified_project_list)
project_df.sort_values('id', inplace=True)
project_df.reset_index(drop=True,inplace=True)
project_df
# Out:
#         id            created_at            updated_at  \
# 0     1001  2019-03-27T13:52:28Z  2022-01-20T06:04:23Z
# 1     1002  2019-03-27T13:52:28Z  2022-11-17T01:11:15Z
# 2     1003  2019-03-27T13:52:28Z  2022-06-08T04:14:19Z
# 3     1007  2019-03-27T13:52:28Z  2022-07-14T12:23:24Z
# 4     1009  2019-03-27T13:52:29Z  2022-12-14T02:28:59Z
# ...    ...                   ...                   ...
# 1357   992  2019-03-27T13:52:26Z  2022-01-05T12:27:23Z
# 1358   993  2019-03-27T13:52:26Z  2022-01-05T12:32:11Z
# 1359   994  2019-03-27T13:52:26Z  2022-01-05T12:39:55Z
# 1360   995  2019-03-27T13:52:27Z  2022-01-05T12:42:50Z
# 1361   999  2019-03-27T13:52:27Z  2022-07-07T12:54:20Z
#
#                                                    name  \
# 0     Prony and Kafeate wind-farms, New Caledonia (3...
# 1            Amayo 40 MW Wind Power Project – Nicaragua
# 2                Renewable Energy Power project by DDWL
# 3              Cataltepe 16MW Wind Farm Project, Turkey
# 4             Kuyucak 25.6 MW Wind Farm Project, Turkey
# ...                                                 ...
# 1357  GS4424 VPA2 African Cookstoves and Water Prorg...
# 1358  GS4424 VPA3 African Cookstoves and Water Progr...
# 1359  GS4424 VPA4 African Cookstoves and Water Progr...
# 1360  GS4424 VPA5 African Cookstoves and Water Progr...
# 1361  Bangna Starch Wastewater Treatment and Biogas ...
#
#                                             description  \
# 0     The project activity involves six wind farms l...
# 1     The main objective of the Amayo Wind Power Pro...
# 2     The main purpose of this project activity is t...
# 3     The Cataltepe 16 MW Wind Farm Project, Turkey,...
# 4     The Kuyucak 25,6 MW Wind Farm Project, Turkey,...
# ...                                                 ...
# 1357  The Micro-Scale Voluntary Project Activity 2 A...
# 1358  The Micro-Scale Voluntary Project Activity 3 A...
# 1359  The Micro-Scale Voluntary Project Activity 4 A...
# 1360  The Micro-Scale Voluntary Project Activity 5 A...
# 1361  The proposed project activity consists of the ...
#
#                                status               gsf_standards_version  \
# 0     GOLD_STANDARD_CERTIFIED_PROJECT  Gold Standard for the Global Goals
# 1     GOLD_STANDARD_CERTIFIED_PROJECT  Gold Standard for the Global Goals
# 2     GOLD_STANDARD_CERTIFIED_PROJECT  Gold Standard for the Global Goals
# 3     GOLD_STANDARD_CERTIFIED_PROJECT                             v1 CASH
# 4     GOLD_STANDARD_CERTIFIED_PROJECT                             v1 CASH
# ...                               ...                                 ...
# 1357  GOLD_STANDARD_CERTIFIED_PROJECT                           v2.2 CASH
# 1358  GOLD_STANDARD_CERTIFIED_PROJECT                           v2.2 CASH
# 1359  GOLD_STANDARD_CERTIFIED_PROJECT                           v2.2 CASH
# 1360  GOLD_STANDARD_CERTIFIED_PROJECT                           v2.2 CASH
# 1361  GOLD_STANDARD_CERTIFIED_PROJECT  Gold Standard for the Global Goals
#
#       estimated_annual_credits crediting_period_start_date  \
# 0                        36339                  2008-04-20
# 1                       120811                  2021-04-12
# 2                        58947                  2020-10-07
# 3                        39724                  2011-04-19
# 4                        71578                  2017-11-11
# ...                        ...                         ...
# 1357                      9719                  2015-12-12
# 1358                      9719                  2015-12-12
# 1359                      9719                  2015-12-12
# 1360                      9179                  2015-12-12
# 1361                     41701                  2009-11-10
#
#      crediting_period_end_date  ... country_code    latitude   longitude  \
# 0                   2022-04-19  ...           NC  -22.190001  166.490005
# 1                   2026-04-11  ...           NI        None        None
# 2                   2025-10-06  ...           IN   22.259556   69.492222
# 3                   2018-04-18  ...           TR   39.516701   27.133301
# 4                   2024-11-10  ...           TR   39.283298   27.883301
# ...                        ...  ...          ...         ...         ...
# 1357                2022-12-11  ...           RW        -2.0        30.1
# 1358                2022-12-11  ...           RW        -2.0        30.1
# 1359                2022-12-11  ...           RW        -2.0        30.1
# 1360                2022-12-11  ...           RW        -2.0        30.1
# 1361                2016-11-09  ...           TH   16.254101    103.3032
#
#       state carbon_stream programme_of_activities  \
# 0      None           VER              Standalone
# 1      None        GS CER              Standalone
# 2      None           VER              Standalone
# 3      None           VER              Standalone
# 4      None           VER              Standalone
# ...     ...           ...                     ...
# 1357   None           VER                     VPA
# 1358   None           VER                     VPA
# 1359   None           VER                     VPA
# 1360   None           VER                     VPA
# 1361   None           VER              Standalone
#
#                           sustainable_development_goals poa_project_id  \
# 0     [{'name': 'Goal 7: Affordable and Clean Energy...            NaN
# 1     [{'name': 'Goal 17: Partnerships for the Goals...            NaN
# 2     [{'name': 'Goal 13: Climate Action', 'issuable...            NaN
# 3     [{'name': 'Goal 8: Decent Work and Economic Gr...            NaN
# 4     [{'name': 'Goal 8: Decent Work and Economic Gr...            NaN
# ...                                                 ...            ...
# 1357  [{'name': 'Goal 7: Affordable and Clean Energy...          757.0
# 1358  [{'name': 'Goal 3: Good Health and Well-Being'...          757.0
# 1359  [{'name': 'Goal 7: Affordable and Clean Energy...          757.0
# 1360  [{'name': 'Goal 3: Good Health and Well-Being'...          757.0
# 1361  [{'name': 'Goal 13: Climate Action', 'issuable...            NaN
#
#      poa_project_sustaincert_id                            poa_project_name
# 0                           NaN                                         NaN
# 1                           NaN                                         NaN
# 2                           NaN                                         NaN
# 3                           NaN                                         NaN
# 4                           NaN                                         NaN
# ...                         ...                                         ...
# 1357                     4424.0  African Cookstoves and Water Programme PoA
# 1358                     4424.0  African Cookstoves and Water Programme PoA
# 1359                     4424.0  African Cookstoves and Water Programme PoA
# 1360                     4424.0  African Cookstoves and Water Programme PoA
# 1361                        NaN                                         NaN
#
# [1362 rows x 27 columns]

# %%
project_df.dtypes
# Out:
# id                                object
# created_at                        object
# updated_at                        object
# name                              object
# description                       object
# status                            object
# gsf_standards_version             object
# estimated_annual_credits           int64
# crediting_period_start_date       object
# crediting_period_end_date         object
# methodology                       object
# type                              object
# size                              object
# sustaincert_id                     int64
# sustaincert_url                   object
# project_developer                 object
# country                           object
# country_code                      object
# latitude                          object
# longitude                         object
# state                             object
# carbon_stream                     object
# programme_of_activities           object
# sustainable_development_goals     object
# poa_project_id                   float64
# poa_project_sustaincert_id       float64
# poa_project_name                  object
# dtype: object

# %%
project_df.isna().sum()
# Out:
# id                                  0
# created_at                          0
# updated_at                          0
# name                                0
# description                         0
# status                              0
# gsf_standards_version               0
# estimated_annual_credits            0
# crediting_period_start_date         0
# crediting_period_end_date           0
# methodology                        14
# type                                0
# size                                0
# sustaincert_id                      0
# sustaincert_url                     0
# project_developer                   0
# country                             0
# country_code                        0
# latitude                          341
# longitude                         341
# state                            1362
# carbon_stream                       0
# programme_of_activities             0
# sustainable_development_goals       0
# poa_project_id                    645
# poa_project_sustaincert_id        645
# poa_project_name                  645
# dtype: int64

# %%
project_df['created_at'] = pd.to_datetime(project_df['created_at'])
project_df['updated_at'] = pd.to_datetime(project_df['updated_at'])
project_df['crediting_period_start_date'] = pd.to_datetime(project_df['crediting_period_start_date'])
project_df['crediting_period_end_date'] = pd.to_datetime(project_df['crediting_period_end_date'])

project_df.dtypes
# Out:
# id                                            object
# created_at                       datetime64[ns, UTC]
# updated_at                       datetime64[ns, UTC]
# name                                          object
# description                                   object
# status                                        object
# gsf_standards_version                         object
# estimated_annual_credits                       int64
# crediting_period_start_date           datetime64[ns]
# crediting_period_end_date             datetime64[ns]
# methodology                                   object
# type                                          object
# size                                          object
# sustaincert_id                                 int64
# sustaincert_url                               object
# project_developer                             object
# country                                       object
# country_code                                  object
# latitude                                      object
# longitude                                     object
# state                                         object
# carbon_stream                                 object
# programme_of_activities                       object
# sustainable_development_goals                 object
# poa_project_id                               float64
# poa_project_sustaincert_id                   float64
# poa_project_name                              object
# dtype: object

# %%
project_df['sustainable_development_goals']
# Out:
# 0       [{'name': 'Goal 7: Affordable and Clean Energy...
# 1       [{'name': 'Goal 17: Partnerships for the Goals...
# 2       [{'name': 'Goal 13: Climate Action', 'issuable...
# 3       [{'name': 'Goal 8: Decent Work and Economic Gr...
# 4       [{'name': 'Goal 8: Decent Work and Economic Gr...
#                               ...
# 1357    [{'name': 'Goal 7: Affordable and Clean Energy...
# 1358    [{'name': 'Goal 3: Good Health and Well-Being'...
# 1359    [{'name': 'Goal 7: Affordable and Clean Energy...
# 1360    [{'name': 'Goal 3: Good Health and Well-Being'...
# 1361    [{'name': 'Goal 13: Climate Action', 'issuable...
# Name: sustainable_development_goals, Length: 1362, dtype: object

# %%
# project_df['sustainable_development_goals'].apply(pd.Series).stack().reset_index(level=1, drop=True)


sustainable_development_goals_list = []
for index, row in project_df.iterrows():
    details_df = pd.json_normalize(row["sustainable_development_goals"])
    details_df["id"] = row["id"]
    sustainable_development_goals_list.append(details_df)

sustainable_development_goals_df = pd.concat(sustainable_development_goals_list).reset_index(drop=True)
sustainable_development_goals_df
# Out:
#                                          name  \
# 0         Goal 7: Affordable and Clean Energy
# 1                     Goal 13: Climate Action
# 2     Goal 8: Decent Work and Economic Growth
# 3         Goal 17: Partnerships for the Goals
# 4                   Goal 4: Quality Education
# ...                                       ...
# 5063      Goal 7: Affordable and Clean Energy
# 5064                  Goal 13: Climate Action
# 5065  Goal 8: Decent Work and Economic Growth
# 5066      Goal 7: Affordable and Clean Energy
# 5067       Goal 3: Good Health and Well-Being
#
#                                       issuable_products    id
# 0                                                    []  1001
# 1     [{'name': 'Verified Emission Reduction', 'abbr...  1001
# 2                                                    []  1001
# 3                                                    []  1002
# 4                                                    []  1002
# ...                                                 ...   ...
# 5063                                                 []   995
# 5064  [{'name': 'Verified Emission Reduction', 'abbr...   999
# 5065                                                 []   999
# 5066                                                 []   999
# 5067  [{'name': 'Averted Disability Adjusted Life Ye...   999
#
# [5068 rows x 3 columns]

# %%
sustainable_development_goals_list = []

for index, row in project_df.iterrows():
    details_df = pd.json_normalize(row["sustainable_development_goals"])
    for i, r1 in details_df.iterrows():
        project_df.at[index, r1['name']] = True

# %%
credit_detail_list = []
for index, row in project_df.iterrows():
    conn.request("GET", f'/projects/{row["id"]}/credits/summary', payload, headers)
    credits = json.loads(conn.getresponse().read().decode())
   
    for i in range(len(credits)):

        for j in range(len(credits[i]['summary'])):

            if(credits[i]['product'] == 'VER'):
                project_df.at[index, credits[i]['product'] +'_'+ credits[i]['summary'][j]['status'].lower() +'_credits'] = credits[i]['summary'][j]['total']


project_df
# Out:
#         id                created_at                updated_at  \
# 0     1001 2019-03-27 13:52:28+00:00 2022-01-20 06:04:23+00:00
# 1     1002 2019-03-27 13:52:28+00:00 2022-11-17 01:11:15+00:00
# 2     1003 2019-03-27 13:52:28+00:00 2022-06-08 04:14:19+00:00
# 3     1007 2019-03-27 13:52:28+00:00 2022-07-14 12:23:24+00:00
# 4     1009 2019-03-27 13:52:29+00:00 2022-12-14 02:28:59+00:00
# ...    ...                       ...                       ...
# 1357   992 2019-03-27 13:52:26+00:00 2022-01-05 12:27:23+00:00
# 1358   993 2019-03-27 13:52:26+00:00 2022-01-05 12:32:11+00:00
# 1359   994 2019-03-27 13:52:26+00:00 2022-01-05 12:39:55+00:00
# 1360   995 2019-03-27 13:52:27+00:00 2022-01-05 12:42:50+00:00
# 1361   999 2019-03-27 13:52:27+00:00 2022-07-07 12:54:20+00:00
#
#                                                    name  \
# 0     Prony and Kafeate wind-farms, New Caledonia (3...
# 1            Amayo 40 MW Wind Power Project – Nicaragua
# 2                Renewable Energy Power project by DDWL
# 3              Cataltepe 16MW Wind Farm Project, Turkey
# 4             Kuyucak 25.6 MW Wind Farm Project, Turkey
# ...                                                 ...
# 1357  GS4424 VPA2 African Cookstoves and Water Prorg...
# 1358  GS4424 VPA3 African Cookstoves and Water Progr...
# 1359  GS4424 VPA4 African Cookstoves and Water Progr...
# 1360  GS4424 VPA5 African Cookstoves and Water Progr...
# 1361  Bangna Starch Wastewater Treatment and Biogas ...
#
#                                             description  \
# 0     The project activity involves six wind farms l...
# 1     The main objective of the Amayo Wind Power Pro...
# 2     The main purpose of this project activity is t...
# 3     The Cataltepe 16 MW Wind Farm Project, Turkey,...
# 4     The Kuyucak 25,6 MW Wind Farm Project, Turkey,...
# ...                                                 ...
# 1357  The Micro-Scale Voluntary Project Activity 2 A...
# 1358  The Micro-Scale Voluntary Project Activity 3 A...
# 1359  The Micro-Scale Voluntary Project Activity 4 A...
# 1360  The Micro-Scale Voluntary Project Activity 5 A...
# 1361  The proposed project activity consists of the ...
#
#                                status               gsf_standards_version  \
# 0     GOLD_STANDARD_CERTIFIED_PROJECT  Gold Standard for the Global Goals
# 1     GOLD_STANDARD_CERTIFIED_PROJECT  Gold Standard for the Global Goals
# 2     GOLD_STANDARD_CERTIFIED_PROJECT  Gold Standard for the Global Goals
# 3     GOLD_STANDARD_CERTIFIED_PROJECT                             v1 CASH
# 4     GOLD_STANDARD_CERTIFIED_PROJECT                             v1 CASH
# ...                               ...                                 ...
# 1357  GOLD_STANDARD_CERTIFIED_PROJECT                           v2.2 CASH
# 1358  GOLD_STANDARD_CERTIFIED_PROJECT                           v2.2 CASH
# 1359  GOLD_STANDARD_CERTIFIED_PROJECT                           v2.2 CASH
# 1360  GOLD_STANDARD_CERTIFIED_PROJECT                           v2.2 CASH
# 1361  GOLD_STANDARD_CERTIFIED_PROJECT  Gold Standard for the Global Goals
#
#       estimated_annual_credits crediting_period_start_date  \
# 0                        36339                  2008-04-20
# 1                       120811                  2021-04-12
# 2                        58947                  2020-10-07
# 3                        39724                  2011-04-19
# 4                        71578                  2017-11-11
# ...                        ...                         ...
# 1357                      9719                  2015-12-12
# 1358                      9719                  2015-12-12
# 1359                      9719                  2015-12-12
# 1360                      9179                  2015-12-12
# 1361                     41701                  2009-11-10
#
#      crediting_period_end_date  ... Goal 5: Gender Equality  \
# 0                   2022-04-19  ...                     NaN
# 1                   2026-04-11  ...                     NaN
# 2                   2025-10-06  ...                     NaN
# 3                   2018-04-18  ...                     NaN
# 4                   2024-11-10  ...                     NaN
# ...                        ...  ...                     ...
# 1357                2022-12-11  ...                     NaN
# 1358                2022-12-11  ...                     NaN
# 1359                2022-12-11  ...                     NaN
# 1360                2022-12-11  ...                     NaN
# 1361                2016-11-09  ...                     NaN
#
#      Goal 1: No Poverty Goal 9: Industry, Innovation and Infrastructure  \
# 0                   NaN                                             NaN
# 1                   NaN                                             NaN
# 2                   NaN                                             NaN
# 3                   NaN                                             NaN
# 4                   NaN                                             NaN
# ...                 ...                                             ...
# 1357                NaN                                             NaN
# 1358                NaN                                             NaN
# 1359                NaN                                             NaN
# 1360                NaN                                             NaN
# 1361                NaN                                             NaN
#
#       Goal 2: Zero Hunger Goal 11: Sustainable Cities and Communities  \
# 0                     NaN                                         NaN
# 1                     NaN                                         NaN
# 2                     NaN                                         NaN
# 3                     NaN                                         NaN
# 4                     NaN                                         NaN
# ...                   ...                                         ...
# 1357                  NaN                                         NaN
# 1358                  NaN                                         NaN
# 1359                  NaN                                         NaN
# 1360                  NaN                                         NaN
# 1361                  NaN                                         NaN
#
#      Goal 16: Peace, Justice and Strong Institutions  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 1357                                             NaN
# 1358                                             NaN
# 1359                                             NaN
# 1360                                             NaN
# 1361                                             NaN
#
#      Goal 10: Reduced Inequalities Goal 14: Life Below Water  \
# 0                              NaN                       NaN
# 1                              NaN                       NaN
# 2                              NaN                       NaN
# 3                              NaN                       NaN
# 4                              NaN                       NaN
# ...                            ...                       ...
# 1357                           NaN                       NaN
# 1358                           NaN                       NaN
# 1359                           NaN                       NaN
# 1360                           NaN                       NaN
# 1361                           NaN                       NaN
#
#      VER_retired_credits VER_issued_credits
# 0               361396.0           464170.0
# 1                    NaN            97279.0
# 2                 3171.0            63911.0
# 3                35869.0            35869.0
# 4               147376.0           148645.0
# ...                  ...                ...
# 1357             17955.0            33561.0
# 1358             15589.0            33595.0
# 1359             19959.0            33306.0
# 1360             14546.0            33530.0
# 1361             12000.0            56059.0
#
# [1362 rows x 46 columns]

# %%
project_df.to_csv('original_data.csv', encoding='utf-8')

# %%
project_df.dtypes
# Out:
# id                                                              object
# created_at                                         datetime64[ns, UTC]
# updated_at                                         datetime64[ns, UTC]
# name                                                            object
# description                                                     object
# status                                                          object
# gsf_standards_version                                           object
# estimated_annual_credits                                         int64
# crediting_period_start_date                             datetime64[ns]
# crediting_period_end_date                               datetime64[ns]
# methodology                                                     object
# type                                                            object
# size                                                            object
# sustaincert_id                                                   int64
# sustaincert_url                                                 object
# project_developer                                               object
# country                                                         object
# country_code                                                    object
# latitude                                                        object
# longitude                                                       object
# state                                                           object
# carbon_stream                                                   object
# programme_of_activities                                         object
# sustainable_development_goals                                   object
# poa_project_id                                                 float64
# poa_project_sustaincert_id                                     float64
# poa_project_name                                                object
# Goal 7: Affordable and Clean Energy                             object
# Goal 13: Climate Action                                         object
# Goal 8: Decent Work and Economic Growth                         object
# Goal 17: Partnerships for the Goals                             object
# Goal 4: Quality Education                                       object
# Goal 15: Life On Land                                           object
# Goal 3: Good Health and Well-Being                              object
# Goal 12: Responsible Production and Consumption                 object
# Goal 6: Clean Water and Sanitation                              object
# Goal 5: Gender Equality                                         object
# Goal 1: No Poverty                                              object
# Goal 9: Industry, Innovation and Infrastructure                 object
# Goal 2: Zero Hunger                                             object
# Goal 11: Sustainable Cities and Communities                     object
# Goal 16: Peace, Justice and Strong Institutions                 object
# Goal 10: Reduced Inequalities                                   object
# Goal 14: Life Below Water                                       object
# VER_retired_credits                                            float64
# VER_issued_credits                                             float64
# dtype: object

# %%
project_df.type.value_counts()
# Out:
# Energy Efficiency - Domestic                663
# Wind                                        219
# Biogas - Heat                               156
# Solar Thermal - Electricity                  92
# Small, Low - Impact Hydro                    56
# Other                                        55
# Biogas - Electricity                         37
# Solar Thermal - Heat                         23
# Biomass, or Liquid Biofuel - Heat            16
# Biomass, or Liquid Biofuel - Electricity     14
# Biogas - Cogeneration                        12
# Energy Efficiency - Industrial                7
# Geothermal                                    7
# Energy Efficiency - Public Sector             3
# Energy Efficiency - Transport Sector          2
# Name: type, dtype: int64

# %%
project_df.country.value_counts()
# Out:
# India          215
# China          199
# Turkey         127
# Rwanda          92
# Uganda          84
#               ...
# Lesotho          1
# Guinea           1
# Aruba            1
# Burundi          1
# Switzerland      1
# Name: country, Length: 74, dtype: int64

# %%
project_df.isna().sum()
# Out:
# id                                                    0
# created_at                                            0
# updated_at                                            0
# name                                                  0
# description                                           0
# status                                                0
# gsf_standards_version                                 0
# estimated_annual_credits                              0
# crediting_period_start_date                           0
# crediting_period_end_date                             0
# methodology                                          14
# type                                                  0
# size                                                  0
# sustaincert_id                                        0
# sustaincert_url                                       0
# project_developer                                     0
# country                                               0
# country_code                                          0
# latitude                                            341
# longitude                                           341
# state                                              1362
# carbon_stream                                         0
# programme_of_activities                               0
# sustainable_development_goals                         0
# poa_project_id                                      645
# poa_project_sustaincert_id                          645
# poa_project_name                                    645
# Goal 7: Affordable and Clean Energy                 591
# Goal 13: Climate Action                               0
# Goal 8: Decent Work and Economic Growth             766
# Goal 17: Partnerships for the Goals                1333
# Goal 4: Quality Education                          1309
# Goal 15: Life On Land                              1099
# Goal 3: Good Health and Well-Being                  519
# Goal 12: Responsible Production and Consumption    1107
# Goal 6: Clean Water and Sanitation                 1044
# Goal 5: Gender Equality                            1082
# Goal 1: No Poverty                                 1174
# Goal 9: Industry, Innovation and Infrastructure    1293
# Goal 2: Zero Hunger                                1334
# Goal 11: Sustainable Cities and Communities        1352
# Goal 16: Peace, Justice and Strong Institutions    1361
# Goal 10: Reduced Inequalities                      1361
# Goal 14: Life Below Water                          1361
# VER_retired_credits                                 367
# VER_issued_credits                                  171
# dtype: int64

# %%
project_df.iloc[: , 27:36] = project_df.iloc[: , 27:36].fillna(False)
# Out:
# C:\Users\balen\AppData\Local\Temp\ipykernel_11108\1473734162.py:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   project_df.iloc[: , 27:36] = project_df.iloc[: , 27:36].fillna(False)

# %%
project_df.drop(columns=['latitude','longitude','state'], axis=1, inplace=True)

# %%
project_df.VER_issued_credits = project_df.VER_issued_credits.fillna(0)
project_df.VER_retired_credits = project_df.VER_retired_credits.fillna(0)

# %%
project_df.to_csv('cleaned_data.csv', encoding='utf-8')
